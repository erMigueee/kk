# %% [markdown]
# <a href="https://colab.research.google.com/github/erMigueee/kk/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1>Un título <h1>
# <h2> Un subtítulo <h2>
# <h3>Texto<h3>
#
# #Título
# ##Subtítulo
# ###Texto

# %%
a=1
b=32
c = a+b
print (c)
# Out:
# 33

# %%
a = 0
